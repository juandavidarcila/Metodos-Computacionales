# %% [markdown]
# <a href="https://colab.research.google.com/github/juandavidarcila/Metodos-Computacionales/blob/main/Semana4/DescensoGradiente.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
import time
import copy

# %%
def Plotter(e):

  fig = plt.figure(figsize=(8,3))
  ax = fig.add_subplot(121)
  ax1 = fig.add_subplot(122)
  ax.set_title('iteracion: {:.0f}'.format(e),fontsize=10)

  return ax,ax1

# %%
ax,ax1 = Plotter(6)

# %%
def f(x):
  #return x**2 + 10*np.sin(x)
  return np.sin(x)/x

# %%
xvalues = np.linspace(-20,20,50)
yvalues = f(xvalues)

# %%
def Derivative(x,f,h=1e-4):
  return (f(x+h)-f(x-h))/(2*h)

# %%
ax,ax1 = Plotter(6)
ax.plot(xvalues,yvalues)
ax
# Out:
# <Axes: title={'center': 'iteracion: 6'}>

# %%
def GradientDescent(f,epochs=100,lr=10):

  # Voy a elegir aleatoria la semilla del algoritmo
  xn = np.random.uniform(-10,10)
  #xn = 10
  History = np.array([])

  for e in range(epochs):

    #El algoritmo
    xn1 = xn - lr*Derivative(xn,f)

    #Actualizamos el punt
    xn = xn1

    # LLenamos la historia
    History = np.append(History,f(xn))

    #Imprimimos

    clear_output(wait=True)
    ax,ax1 = Plotter(e)
    ax.plot(xvalues,yvalues)

    ax.scatter(xn,f(xn),color='r')
    ax1.plot(History,'.-',color='k')

    plt.show()

# %%
GradientDescent(f)
