# %% [markdown]
# <a href="https://colab.research.google.com/github/juandavidarcila/Metodos-Computacionales/blob/main/Semana5/Integracion_Trapecio2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate
import sympy as sym

# %%
x_ = sym.Symbol('x',real=True)
F = sym.sin(2*x_)*sym.exp(-x_)
F
# Out:
# exp(-x)*sin(2*x)

# %%
Iexacta = sym.integrate(F,(x_,0,2*np.pi))

# %%
a = 0*-2*np.pi
b = 2*np.pi
f = lambda x: np.sin(2*x)*np.exp(-x)
x = np.linspace(a,b,100)
y = f(x)

# %%
N = 22 # Controlamos el numero de trapecios
x1 = np.linspace(a,b, N+1)
y1 = f(x1)
yp = np.interp(x1,x1,y1)

# %%
plt.plot(x,y,color='k')
plt.plot(x1,yp,marker='*',color='r')
#plt.fill_between(x,y,color='b',alpha=0.5)
plt.fill_between(x1,yp,color='b',alpha=0.5)

# %%
#calculamos h
h = x1[1] - x1[0]
h
# Out:
# np.float64(0.28559933214452665)

# %%
x1
# Out:
# array([0.        , 0.28559933, 0.57119866, 0.856798  , 1.14239733,
#        1.42799666, 1.71359599, 1.99919533, 2.28479466, 2.57039399,
#        2.85599332, 3.14159265, 3.42719199, 3.71279132, 3.99839065,
#        4.28398998, 4.56958931, 4.85518865, 5.14078798, 5.42638731,
#        5.71198664, 5.99758598, 6.28318531])

# %%
# INtegral con trapecio
Integral = 0
Integral += 0.5*(f(x1[0]) + f(x1[-1]))

for i in range(1,len(x1)-1):
    Integral += f(x1[i])

Integral *= h

Integral
# Out:
# np.float64(0.3856661577820507)

# %%
# Error en el trapecio
h**2
# Out:
# np.float64(0.08156697852139966)

# %%
# Integral a la simpson
Integral1 = 0
Integral1 += f(x1[0]) + f(x1[-1])
Integral1 += 4*np.sum( f(x1[1:-1:2]) )
Integral1 += 2*np.sum( f(x1[2:-2:2]) )
Integral1 *= h/3
Integral1
# Out:
# np.float64(0.399312324995343)

# %%
print(Integral,Integral1,Iexacta)
# Out:
# 0.3856661577820507 0.399312324995343 0.399253022907317

# %%
h**4
# Out:
# np.float64(0.006653171985110473)

# %%
I = 0
I += f(x1[0]) + f(x1[-1])
for i in range(1,len(x1)-1):
    if i%2 == 0:
      I += 2*f(x1[i])
    else:
      I += 4*f(x1[i])
I *= h/3
I
# Out:
# np.float64(0.399312324995343)

# %%
n = 2
x = np.linspace(-1,1,n+1)
y = np.linspace(-1,1,n+1)
X,Y = np.meshgrid(x,y)

# %%
plt.scatter(X,Y)
