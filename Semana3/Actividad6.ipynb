# %% [markdown]
# <a href="https://colab.research.google.com/github/juandavidarcila/Metodos-Computacionales/blob/main/Semana3/Actividad6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def x1(t):
  r1 = 50-0.2*t-0.1*t**2
  return r1

# %%
def x2(t):
  r2 = t**2 + 0.1*t**3
  return r2

# %%
# Primer paso: pintamos la funcion
t = np.linspace(1, 6, 50)
plt.plot(x, x1(t))
plt.plot(x, x2(t))
plt.show()

# %%
def Function(x1,x2):
  return x1(t)-x2(t)

# %%
|
# Out:
#   File "/tmp/ipython-input-525519296.py", line 1
#     |
#     ^
# SyntaxError: invalid syntax

# %%
plt.plot(x, y)
plt.axhline(y=0, color='r', linestyle='--')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-52193492.py in <cell line: 0>()
# ----> 1 plt.plot(x, y)
#       2 plt.axhline(y=0, color='r', linestyle='--')
#
# NameError: name 'y' is not defined
